# %%
import pandas as pd
import duckdb
import os

print("Pandas version:", pd.__version__)
print("DuckDB version:", duckdb.__version__)
# Out:
# Pandas version: 2.3.3
# DuckDB version: 1.4.3

# %% [markdown]
# # Dataset Occurrence u observaciones

# %%
import duckdb
import pandas as pd

urlo = 'https://www.dropbox.com/scl/fi/i9sshclfbojl8az397ce0/Occurrence.txt?rlkey=daw5f2p78yn1r5bt67vdyk1yv&st=0yc5vcl1&dl=1'

con = duckdb.connect(database=':memory:')

# Traer los primeros 5 registros a Pandas usando la variable
df = con.execute(f"""
    SELECT *
    FROM read_csv_auto('{urlo}')
    LIMIT 5
""").fetchdf()  # o .df() también funciona

df.head()
# Out:
#         id                                       occurrenceID catalogNumber  \
# 0     9@XC  https://data.biodiversitydata.nl/xeno-canto/ob...           XC9
# 1     9@XC  https://data.biodiversitydata.nl/xeno-canto/ob...           XC9
# 2    99@XC  https://data.biodiversitydata.nl/xeno-canto/ob...          XC99
# 3    99@XC  https://data.biodiversitydata.nl/xeno-canto/ob...          XC99
# 4  9999@XC  https://data.biodiversitydata.nl/xeno-canto/ob...        XC9999
#
#       basisOfRecord           collectionCode dynamicProperties  \
# 0  HumanObservation  Wildlife sounds - Birds              None
# 1  HumanObservation  Wildlife sounds - Birds              None
# 2  HumanObservation  Wildlife sounds - Birds              None
# 3  HumanObservation  Wildlife sounds - Birds              None
# 4  HumanObservation  Wildlife sounds - Birds              None
#
#   otherCatalogNumbers       genus specificEpithet infraspecificEpithet  ...  \
# 0                None  Synallaxis          azarae                media  ...
# 1                None  Synallaxis          azarae                media  ...
# 2                None      Turdus       hauxwelli                 None  ...
# 3                None      Turdus       hauxwelli                 None  ...
# 4                None  Myrmothera     campanisona              signata  ...
#
#   verbatimEventDate                                         fieldNotes  \
# 0        12-08-2002  two birds trip:http://www.cs.bris.ac.uk/home/p...
# 1        12-08-2002  two birds trip:http://www.cs.bris.ac.uk/home/p...
# 2        01-10-2003   trip:http://www.cs.bris.ac.uk/home/planque/Peru/
# 3        01-10-2003   trip:http://www.cs.bris.ac.uk/home/planque/Peru/
# 4        04-03-1998                                               None
#
#   behavior   sex lifeStage     preparations  \
# 0     song  None      None  field recording
# 1     song  None      None  field recording
# 2     song  None      None  field recording
# 3     song  None      None  field recording
# 4     song  None      None  field recording
#
#                                           references  \
# 0  https://data.biodiversitydata.nl/xeno-canto/ob...
# 1  https://data.biodiversitydata.nl/xeno-canto/ob...
# 2  https://data.biodiversitydata.nl/xeno-canto/ob...
# 3  https://data.biodiversitydata.nl/xeno-canto/ob...
# 4  https://data.biodiversitydata.nl/xeno-canto/ob...
#
#                                  Associated Taxa       rightsHolder   license
# 0                                           None        Bob Planqué  CC BY-NC
# 1                                           None        Bob Planqué  CC BY-NC
# 2                                           None        Bob Planqué  CC BY-NC
# 3                                           None        Bob Planqué  CC BY-NC
# 4  has background sounds: Selenidera reinwardtii  Allen T. Chartier  CC BY-NC
#
# [5 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     5 non-null      object
#  1   occurrenceID           5 non-null      object
#  2   catalogNumber          5 non-null      object
#  3   basisOfRecord          5 non-null      object
#  4   collectionCode         5 non-null      object
#  5   dynamicProperties      0 non-null      object
#  6   otherCatalogNumbers    0 non-null      object
#  7   genus                  5 non-null      object
#  8   specificEpithet        5 non-null      object
#  9   infraspecificEpithet   3 non-null      object
#  10  scientificName         5 non-null      object
#  11  taxonRank              5 non-null      object
#  12  kingdom                5 non-null      object
#  13  family                 5 non-null      object
#  14  higherClassification   5 non-null      object
#  15  nomenclaturalCode      5 non-null      object
#  16  identificationRemarks  0 non-null      object
#  17  vernacularName         5 non-null      object
#  18  longitudeDecimal       5 non-null      float64
#  19  latitudeDecimal        5 non-null      float64
#  20  geodeticDatum          5 non-null      object
#  21  country                5 non-null      object
#  22  locality               5 non-null      object
#  23  verbatimElevation      5 non-null      object
#  24  recordedBy             5 non-null      object
#  25  eventDate              5 non-null      datetime64[us]
#  26  eventTime              4 non-null      object
#  27  verbatimEventDate      5 non-null      object
#  28  fieldNotes             4 non-null      object
#  29  behavior               5 non-null      object
#  30  sex                    0 non-null      object
#  31  lifeStage              0 non-null      object
#  32  preparations           5 non-null      object
#  33  references             5 non-null      object
#  34  Associated Taxa        1 non-null      object
#  35  rightsHolder           5 non-null      object
#  36  license                5 non-null      object
# dtypes: datetime64[us](1), float64(2), object(34)
# memory usage: 1.6+ KB

# %%
import duckdb

urlo = 'https://www.dropbox.com/scl/fi/i9sshclfbojl8az397ce0/Occurrence.txt?rlkey=daw5f2p78yn1r5bt67vdyk1yv&st=0yc5vcl1&dl=1'
con = duckdb.connect(database=':memory:')

# Contar ocurrencias por país y ordenar de mayor a menor
df_country_counts = con.execute(f"""
    SELECT country, COUNT(*) AS num_records
    FROM read_csv_auto('{urlo}')
    GROUP BY country
    ORDER BY num_records DESC
""").fetchdf()

# Mostrar los primeros países con más registros
print(df_country_counts.head(20))
# Out:
#            country  num_records
# 0    United States       136821
# 1           Brazil       129488
# 2   United Kingdom       127166
# 3           France       113395
# 4         Colombia        68952
# 5          Ecuador        63606
# 6            Spain        62638
# 7          Germany        60480
# 8           Sweden        47175
# 9           Mexico        43797
# 10          Poland        39300
# 11     Netherlands        35448
# 12           China        34261
# 13           India        33301
# 14            Peru        31302
# 15       Australia        30171
# 16    South Africa        28304
# 17       Argentina        26280
# 18       Indonesia        22773
# 19        Malaysia        22524

# %%
# Aproximación geográfica de Europa usando las columnas correctas
min_lat, max_lat = 35.0, 71.0
min_lon, max_lon = -10.0, 40.0

urlo = 'https://www.dropbox.com/scl/fi/i9sshclfbojl8az397ce0/Occurrence.txt?rlkey=daw5f2p78yn1r5bt67vdyk1yv&st=0yc5vcl1&dl=1'
df_europe_geo = con.execute(f"""
    SELECT *
    FROM read_csv_auto('{urlo}')
    WHERE latitudeDecimal BETWEEN {min_lat} AND {max_lat}
      AND longitudeDecimal BETWEEN {min_lon} AND {max_lon}
    LIMIT 1000
""").fetchdf()

df_europe_geo.head()

print("Número de filas:", len(df_europe_geo))
print("Número de columnas:", df_europe_geo.shape[1])
# Out:
# Número de filas: 1000
# Número de columnas: 37

# %%
# Aproximación geográfica de Europa sin límite
min_lat, max_lat = 35.0, 71.0
min_lon, max_lon = -10.0, 40.0

urlo = 'https://www.dropbox.com/scl/fi/i9sshclfbojl8az397ce0/Occurrence.txt?rlkey=daw5f2p78yn1r5bt67vdyk1yv&st=0yc5vcl1&dl=1'
df_europe_geo = con.execute(f"""
    SELECT *
    FROM read_csv_auto('{urlo}')
    WHERE latitudeDecimal BETWEEN {min_lat} AND {max_lat}
      AND longitudeDecimal BETWEEN {min_lon} AND {max_lon}
""").fetchdf()

print("Número de filas:", len(df_europe_geo))
print("Número de columnas:", df_europe_geo.shape[1])
# Out:
# Número de filas: 627360
# Número de columnas: 37

# %%
import duckdb

# URL del CSV en Dropbox
urlo = 'https://www.dropbox.com/scl/fi/i9sshclfbojl8az397ce0/Occurrence.txt?rlkey=daw5f2p78yn1r5bt67vdyk1yv&st=0yc5vcl1&dl=1'

# Conexión en memoria
con = duckdb.connect()

# Ejecutar consulta SQL con f-string para interpolar la variable
result = con.execute(f"""
    SELECT *
    FROM read_csv_auto('{urlo}')
    WHERE country = 'Spain'
""").df()

# Mostrar resultados
result.head()
# Out:
#           id                                       occurrenceID catalogNumber  \
# 0  999933@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC999933
# 1  999870@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC999870
# 2  999857@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC999857
# 3  999856@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC999856
# 4  999830@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC999830
#
#         basisOfRecord           collectionCode  \
# 0  MachineObservation  Wildlife sounds - Birds
# 1    HumanObservation  Wildlife sounds - Birds
# 2    HumanObservation  Wildlife sounds - Birds
# 3    HumanObservation  Wildlife sounds - Birds
# 4  MachineObservation  Wildlife sounds - Birds
#
#                                    dynamicProperties otherCatalogNumbers  \
# 0                                               None                None
# 1  {"recordingDevice":"Zoom H5","microphone":"Tel...                None
# 2  {"recordingDevice":"Zoom h1n","microphone":"2x...                None
# 3  {"recordingDevice":"Zoom h1n","microphone":"2x...                None
# 4               {"recordingDevice":"PARABOLIC DISH"}                None
#
#      genus specificEpithet infraspecificEpithet  ... verbatimEventDate  \
# 0   Rallus       aquaticus                 None  ...        2025-05-20
# 1   Cettia           cetti                 None  ...        2025-05-17
# 2  Curruca         iberiae                 None  ...        2025-04-20
# 3  Curruca          undata                 None  ...        2025-04-27
# 4   Passer      domesticus                 None  ...        2025-05-19
#
#                                           fieldNotes               behavior  \
# 0                   animal seen:no; playback used:no  nocturnal flight call
# 1  Singing from a patch of brambles.; animal seen...                   song
# 2                  animal seen:yes; playback used:no             song, call
# 3                  animal seen:yes; playback used:no                   song
# 4                   animal seen:no; playback used:no                   call
#
#             sex  lifeStage     preparations  \
# 0          None       None  field recording
# 1  undetermined  uncertain  field recording
# 2          male      adult  field recording
# 3          male       None  field recording
# 4  undetermined  uncertain  field recording
#
#                                           references  \
# 0  https://data.biodiversitydata.nl/xeno-canto/ob...
# 1  https://data.biodiversitydata.nl/xeno-canto/ob...
# 2  https://data.biodiversitydata.nl/xeno-canto/ob...
# 3  https://data.biodiversitydata.nl/xeno-canto/ob...
# 4  https://data.biodiversitydata.nl/xeno-canto/ob...
#
#                                      Associated Taxa           rightsHolder  \
# 0                                               None            Jorge Rodal
# 1  has background sounds: Cuculus canorus|Oriolus...             João Tomás
# 2                                               None  Jorge Valella Robledo
# 3                                               None  Jorge Valella Robledo
# 4                                               None         Sergi Carreras
#
#     license
# 0  CC BY-NC
# 1  CC BY-NC
# 2  CC BY-NC
# 3  CC BY-NC
# 4  CC BY-NC
#
# [5 rows x 37 columns]

# %% [markdown]
# # Datos de dataset Multimedia

# %%
con = duckdb.connect(database=':memory:')

urlm = 'https://www.dropbox.com/scl/fi/z8lpwp3qnvz0r8lsc5qi1/Multimedia.txt?rlkey=yk05peoav2vw5ojbkqsebx9n7&st=q63xenjk&dl=1'

# Traer los primeros 5 registros a Pandas
dfm = con.execute(f"""
    SELECT *
    FROM read_csv_auto('{urlm}')
    LIMIT 5
""").fetchdf()

dfm.head()
# Out:
#   CoreId                     associatedObservationReference  \
# 0   9@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 1   9@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 2   9@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 3   9@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
# 4   9@XC  https://data.biodiversitydata.nl/xeno-canto/ob...
#
#                                           Identifier        type  Rating  \
# 0  https://xeno-canto.org/sounds/uploaded/OH38YHK...  StillImage    <NA>
# 1  https://xeno-canto.org/sounds/uploaded/OH38YHK...  StillImage    <NA>
# 2  https://xeno-canto.org/sounds/uploaded/OH38YHK...  StillImage    <NA>
# 3  https://xeno-canto.org/sounds/uploaded/OH38YHK...  StillImage    <NA>
# 4  https://xeno-canto.org/sounds/uploaded/OH38YHK...       Sound       5
#
#                                rightsHolder  \
# 0  Stichting Xeno-canto voor Natuurgeluiden
# 1  Stichting Xeno-canto voor Natuurgeluiden
# 2  Stichting Xeno-canto voor Natuurgeluiden
# 3  Stichting Xeno-canto voor Natuurgeluiden
# 4                               Bob Planqué
#
#                                     creator  \
# 0  Stichting Xeno-canto voor Natuurgeluiden
# 1  Stichting Xeno-canto voor Natuurgeluiden
# 2  Stichting Xeno-canto voor Natuurgeluiden
# 3  Stichting Xeno-canto voor Natuurgeluiden
# 4                               Bob Planqué
#
#                                            accessURI     format  \
# 0  https://xeno-canto.org/sounds/uploaded/OH38YHK...  image/png
# 1  https://xeno-canto.org/sounds/uploaded/OH38YHK...  image/png
# 2  https://xeno-canto.org/sounds/uploaded/OH38YHK...  image/png
# 3  https://xeno-canto.org/sounds/uploaded/OH38YHK...  image/png
# 4  https://xeno-canto.org/sounds/uploaded/OH38YHK...  audio/mp3
#
#      variantLiteral description  \
# 0  ac:MediumQuality        None
# 1  ac:MediumQuality        None
# 2  ac:MediumQuality        None
# 3  ac:MediumQuality        None
# 4    ac:BestQuality        17 s
#
#                                              caption  \
# 0  Oscillogram of the first ten seconds of the so...
# 1  Oscillogram of the first ten seconds of the so...
# 2  Spectrogram of the first ten seconds of the so...
# 3  Spectrogram of the first ten seconds of the so...
# 4                                               None
#
#                            resourceCreationTechnique captureDevice  \
# 0                                               None          None
# 1                                               None          None
# 2                                               None          None
# 3                                               None          None
# 4  automatic recording: no; bitrate: 64000 bps; b...          None
#
#   physicalSetting          license
# 0            None  CC BY-NC-SA 3.0
# 1            None  CC BY-NC-SA 3.0
# 2            None  CC BY-NC-SA 3.0
# 3            None  CC BY-NC-SA 3.0
# 4         Natural  CC BY-NC-SA 3.0

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CoreId                          5 non-null      object
#  1   associatedObservationReference  5 non-null      object
#  2   Identifier                      5 non-null      object
#  3   type                            5 non-null      object
#  4   Rating                          1 non-null      Int64
#  5   rightsHolder                    5 non-null      object
#  6   creator                         5 non-null      object
#  7   accessURI                       5 non-null      object
#  8   format                          5 non-null      object
#  9   variantLiteral                  5 non-null      object
#  10  description                     1 non-null      object
#  11  caption                         4 non-null      object
#  12  resourceCreationTechnique       1 non-null      object
#  13  captureDevice                   0 non-null      object
#  14  physicalSetting                 1 non-null      object
#  15  license                         5 non-null      object
# dtypes: Int64(1), object(15)
# memory usage: 777.0+ bytes

# %% [markdown]
# # Union de los datasets Occurrence.txt y Multimedia.txt con ID=CoreId

# %%
# 🔹 Conexión en memoria
con = duckdb.connect(database=':memory:')

# 🔹 URLs de los archivos en Dropbox
urlo = "https://www.dropbox.com/scl/fi/i9sshclfbojl8az397ce0/Occurrence.txt?rlkey=daw5f2p78yn1r5bt67vdyk1yv&st=0yc5vcl1&dl=1"
urlm = "https://www.dropbox.com/scl/fi/z8lpwp3qnvz0r8lsc5qi1/Multimedia.txt?rlkey=yk05peoav2vw5ojbkqsebx9n7&st=q63xenjk&dl=1"

# 🔹 Crear tabla Occurrence filtrada solo para España y Alemania
con.execute(f"""
CREATE TABLE occurrence_es AS
SELECT *
FROM read_csv_auto('{urlo}', header=True)
WHERE country IN ('Spain', 'Germany')
""")

# 🔹 Crear tabla Multimedia
con.execute(f"""
CREATE TABLE multimedia AS
SELECT *
FROM read_csv_auto('{urlm}', header=True)
""")

# 🔹 Hacer JOIN usando Occurrence.id = Multimedia.CoreId
query = """
SELECT 
    o.*, 
    m.Identifier, 
    m.type, 
    m.format, 
    m.accessURI
FROM occurrence_es o
LEFT JOIN multimedia m
    ON o.id = m.CoreId
"""

# 🔹 Ejecutar consulta y obtener DataFrame
# df_joined = con.execute(query).fetchdf()

# 🔹 Mostrar las primeras filas
# print(df_joined.head())

# %% [markdown]
# *Limpieza de duplicados y agrupacion Dataset filtrado con datos de España y Alemania

# %%
import duckdb

# URL del archivo en Dropbox
url = 'https://www.dropbox.com/scl/fi/bgb8rrylp65egjs56m2jc/df_joined.csv?rlkey=0ntccu09bu9v7qujj5prq8nqz&st=tihqh9le&dl=1'

# Conexión en memoria
con = duckdb.connect(database=':memory:')

# Leer CSV directamente desde la URL
df = con.execute(f"""
    SELECT *
    FROM read_csv_auto('{url}')
""").fetchdf()

# Mostrar las primeras filas
df.head()
# Out:
#           id                                       occurrenceID catalogNumber  \
# 0  839019@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC839019
# 1  839019@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC839019
# 2  839019@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC839019
# 3  839019@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC839019
# 4  839019@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC839019
#
#       basisOfRecord           collectionCode  \
# 0  HumanObservation  Wildlife sounds - Birds
# 1  HumanObservation  Wildlife sounds - Birds
# 2  HumanObservation  Wildlife sounds - Birds
# 3  HumanObservation  Wildlife sounds - Birds
# 4  HumanObservation  Wildlife sounds - Birds
#
#                                    dynamicProperties otherCatalogNumbers  \
# 0  {"recordingDevice":"MIXPRE 6","microphone":"Te...                None
# 1  {"recordingDevice":"MIXPRE 6","microphone":"Te...                None
# 2  {"recordingDevice":"MIXPRE 6","microphone":"Te...                None
# 3  {"recordingDevice":"MIXPRE 6","microphone":"Te...                None
# 4  {"recordingDevice":"MIXPRE 6","microphone":"Te...                None
#
#         genus specificEpithet infraspecificEpithet  ...  lifeStage  \
# 0  Hieraaetus        pennatus                 None  ...  uncertain
# 1  Hieraaetus        pennatus                 None  ...  uncertain
# 2  Hieraaetus        pennatus                 None  ...  uncertain
# 3  Hieraaetus        pennatus                 None  ...  uncertain
# 4  Hieraaetus        pennatus                 None  ...  uncertain
#
#       preparations                                         references  \
# 0  field recording  https://data.biodiversitydata.nl/xeno-canto/ob...
# 1  field recording  https://data.biodiversitydata.nl/xeno-canto/ob...
# 2  field recording  https://data.biodiversitydata.nl/xeno-canto/ob...
# 3  field recording  https://data.biodiversitydata.nl/xeno-canto/ob...
# 4  field recording  https://data.biodiversitydata.nl/xeno-canto/ob...
#
#                                  Associated Taxa  rightsHolder   license  \
# 0  has background sounds: Phylloscopus collybita  Jordi Calvet  CC BY-NC
# 1  has background sounds: Phylloscopus collybita  Jordi Calvet  CC BY-NC
# 2  has background sounds: Phylloscopus collybita  Jordi Calvet  CC BY-NC
# 3  has background sounds: Phylloscopus collybita  Jordi Calvet  CC BY-NC
# 4  has background sounds: Phylloscopus collybita  Jordi Calvet  CC BY-NC
#
#                                           Identifier        type     format  \
# 0  https://xeno-canto.org/sounds/uploaded/PNYKOPB...  StillImage  image/png
# 1  https://xeno-canto.org/sounds/uploaded/PNYKOPB...  StillImage  image/png
# 2  https://xeno-canto.org/sounds/uploaded/PNYKOPB...  StillImage  image/png
# 3  https://xeno-canto.org/sounds/uploaded/PNYKOPB...  StillImage  image/png
# 4  https://xeno-canto.org/sounds/uploaded/PNYKOPB...       Sound  audio/mp3
#
#                                            accessURI
# 0  https://xeno-canto.org/sounds/uploaded/PNYKOPB...
# 1  https://xeno-canto.org/sounds/uploaded/PNYKOPB...
# 2  https://xeno-canto.org/sounds/uploaded/PNYKOPB...
# 3  https://xeno-canto.org/sounds/uploaded/PNYKOPB...
# 4  https://xeno-canto.org/sounds/uploaded/PNYKOPB...
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (725663, 41)

# %%
#limpiar dataset de duplicados 


# 1️⃣ Ver duplicados exactos
duplicados = df[df.duplicated()]
print(f"Número de filas duplicadas exactas: {len(duplicados)}")

# 2️⃣ Ver duplicados por 'id' (varias imágenes por ocurrencia)
duplicados_id = df[df.duplicated(subset=['id'], keep=False)]
print(f"Número de IDs con varias filas: {duplicados_id['id'].nunique()}")

# 3️⃣ Eliminar duplicados exactos
df_sin_duplicados = df.drop_duplicates()
print(f"Tamaño después de eliminar duplicados exactos: {df_sin_duplicados.shape}")

# 4️⃣ Agrupar múltiples imágenes por ocurrencia 
df_agrupado = df_sin_duplicados.groupby('id').agg({
    'Identifier': list,
    'type': list,
    'format': list,
    'accessURI': list,
    'country': 'first',  # mantener país
    # puedes agregar otras columnas de Occurrence que quieras conservar
}).reset_index()

print(f"Tamaño después de agrupar por ID: {df_agrupado.shape}")

# 5️⃣ Guardar DataFrame limpio
#df_agrupado.to_csv('df_joined_limpio.csv', index=False)


#print("¡DataFrame limpio guardado en CSV!")
# Out:
# Número de filas duplicadas exactas: 536234
# Número de IDs con varias filas: 62692
# Tamaño después de eliminar duplicados exactos: (189429, 41)
# Tamaño después de agrupar por ID: (63475, 6)
