# %% [markdown]
# Importar librerías

# %%
import duckdb
import pandas as pd
from pathlib import Path

# %% [markdown]
# Crear las rutas de acceso

# %%
# Ruta base donde se descomprimió el dataset Darwin Core Archive
folder = Path.home() / "Downloads" / "wildlife-sounds-birds_dwca"

# Archivos de entrada
occ_path = (folder / "Occurrence.txt").as_posix()
mult_path = (folder / "Multimedia.txt").as_posix()

# Archivo de salida (dataset combinado)
out_csv = (Path.home() / "Downloads" / "birds_spain_joined.csv").as_posix()

print("Archivo Occurrence:", occ_path)
print("Archivo Multimedia:", mult_path)
print("Archivo de salida:", out_csv)
# Out:
# Archivo Occurrence: C:/Users/anto-/Downloads/wildlife-sounds-birds_dwca/Occurrence.txt
# Archivo Multimedia: C:/Users/anto-/Downloads/wildlife-sounds-birds_dwca/Multimedia.txt
# Archivo de salida: C:/Users/anto-/Downloads/birds_spain_joined.csv

# %% [markdown]
# Crear la conexión DuckDB

# %%
# Conexión a DuckDB en memoria
con = duckdb.connect(database=":memory:")

print("Conexión establecida correctamente.")
# Out:
# Conexión establecida correctamente.

# %% [markdown]
# Cargamos Ocurrence, filtros para España y multimedia

# %%
# Cargar Occurrence.txt y filtrar registros donde country = 'Spain'
con.execute(f"""
    CREATE OR REPLACE TABLE occurrence_spain AS
    SELECT *
    FROM read_csv_auto('{occ_path}')
    WHERE country = 'Spain';
""")

print("Tabla occurrence_spain creada correctamente.")
# Out:
# Tabla occurrence_spain creada correctamente.

# %%
# Cargar Multimedia.txt completo
con.execute(f"""
    CREATE OR REPLACE TABLE multimedia AS
    SELECT *
    FROM read_csv_auto('{mult_path}');
""")

print("Tabla multimedia creada correctamente.")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Tabla multimedia creada correctamente.

# %% [markdown]
# Inspeccionar columnas para validar el JOIN

# %%
# Revisar columnas de occurrence_spain
print("Columnas de occurrence_spain:")
display(con.execute("PRAGMA table_info(occurrence_spain);").fetchdf())

# Revisar columnas de multimedia
print("Columnas de multimedia:")
display(con.execute("PRAGMA table_info(multimedia);").fetchdf())
# Out:
# Columnas de occurrence_spain:
#     cid                   name     type  notnull dflt_value     pk
# 0     0                     id  VARCHAR    False       None  False
# 1     1           occurrenceID  VARCHAR    False       None  False
# 2     2          catalogNumber  VARCHAR    False       None  False
# 3     3          basisOfRecord  VARCHAR    False       None  False
# 4     4         collectionCode  VARCHAR    False       None  False
# 5     5      dynamicProperties  VARCHAR    False       None  False
# 6     6    otherCatalogNumbers  VARCHAR    False       None  False
# 7     7                  genus  VARCHAR    False       None  False
# 8     8        specificEpithet  VARCHAR    False       None  False
# 9     9   infraspecificEpithet  VARCHAR    False       None  False
# 10   10         scientificName  VARCHAR    False       None  False
# 11   11              taxonRank  VARCHAR    False       None  False
# 12   12                kingdom  VARCHAR    False       None  False
# 13   13                 family  VARCHAR    False       None  False
# 14   14   higherClassification  VARCHAR    False       None  False
# 15   15      nomenclaturalCode  VARCHAR    False       None  False
# 16   16  identificationRemarks  VARCHAR    False       None  False
# 17   17         vernacularName  VARCHAR    False       None  False
# 18   18       longitudeDecimal   DOUBLE    False       None  False
# 19   19        latitudeDecimal   DOUBLE    False       None  False
# 20   20          geodeticDatum  VARCHAR    False       None  False
# 21   21                country  VARCHAR    False       None  False
# 22   22               locality  VARCHAR    False       None  False
# 23   23      verbatimElevation  VARCHAR    False       None  False
# 24   24             recordedBy  VARCHAR    False       None  False
# 25   25              eventDate     DATE    False       None  False
# 26   26              eventTime     TIME    False       None  False
# 27   27      verbatimEventDate  VARCHAR    False       None  False
# 28   28             fieldNotes  VARCHAR    False       None  False
# 29   29               behavior  VARCHAR    False       None  False
# 30   30                    sex  VARCHAR    False       None  False
# 31   31              lifeStage  VARCHAR    False       None  False
# 32   32           preparations  VARCHAR    False       None  False
# 33   33             references  VARCHAR    False       None  False
# 34   34        Associated Taxa  VARCHAR    False       None  False
# 35   35           rightsHolder  VARCHAR    False       None  False
# 36   36                license  VARCHAR    False       None  False
# Columnas de multimedia:
#     cid                            name     type  notnull dflt_value     pk
# 0     0                          CoreId  VARCHAR    False       None  False
# 1     1  associatedObservationReference  VARCHAR    False       None  False
# 2     2                      Identifier  VARCHAR    False       None  False
# 3     3                            type  VARCHAR    False       None  False
# 4     4                          Rating   BIGINT    False       None  False
# 5     5                    rightsHolder  VARCHAR    False       None  False
# 6     6                         creator  VARCHAR    False       None  False
# 7     7                       accessURI  VARCHAR    False       None  False
# 8     8                          format  VARCHAR    False       None  False
# 9     9                  variantLiteral  VARCHAR    False       None  False
# 10   10                     description  VARCHAR    False       None  False
# 11   11                         caption  VARCHAR    False       None  False
# 12   12       resourceCreationTechnique  VARCHAR    False       None  False
# 13   13                   captureDevice  VARCHAR    False       None  False
# 14   14                 physicalSetting  VARCHAR    False       None  False
# 15   15                         license  VARCHAR    False       None  False

# %% [markdown]
# Ejecutamos el JOIN entre Occurence y Multimedia

# %%
# Unión entre Occurrence (id) y Multimedia (CoreId)
# Además añadimos columnas multimedia relevantes: Identifier (URL), type, Rating

con.execute("""
    CREATE OR REPLACE TABLE birds_spain AS
    SELECT
        o.*,
        m.Identifier AS audio_url,
        m.type       AS media_type,
        m.Rating     AS media_rating
    FROM occurrence_spain o
    LEFT JOIN multimedia m
        ON o.id = m.CoreId;
""")

print("Tabla birds_spain creada correctamente.")
# Out:
# Tabla birds_spain creada correctamente.

# %% [markdown]
# Exportar el dataset combinado a CSV

# %%
# Exportar el dataset final
con.execute(f"""
    COPY birds_spain
    TO '{out_csv}'
    WITH (HEADER, DELIMITER ',');
""")

print("CSV final exportado correctamente en:", out_csv)
# Out:
# CSV final exportado correctamente en: C:/Users/anto-/Downloads/birds_spain_joined.csv

# %% [markdown]
# Cargar el CSV en pandas para el análisis

# %%
# Cargar dataset combinado en pandas para continuar el análisis
df_spain = pd.read_csv(out_csv)

print("Dimensiones del dataframe final:", df_spain.shape)
df_spain.head()
# Out:
# C:\Users\anto-\AppData\Local\Temp\ipykernel_38504\4057851898.py:2: DtypeWarning: Columns (6,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_spain = pd.read_csv(out_csv)
# Dimensiones del dataframe final: (369321, 40)
#           id                                       occurrenceID catalogNumber  \
# 0  902066@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC902066
# 1  902066@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC902066
# 2  902066@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC902066
# 3  902066@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC902066
# 4  902066@XC  https://data.biodiversitydata.nl/xeno-canto/ob...      XC902066
#
#       basisOfRecord           collectionCode  \
# 0  HumanObservation  Wildlife sounds - Birds
# 1  HumanObservation  Wildlife sounds - Birds
# 2  HumanObservation  Wildlife sounds - Birds
# 3  HumanObservation  Wildlife sounds - Birds
# 4  HumanObservation  Wildlife sounds - Birds
#
#                                    dynamicProperties otherCatalogNumbers  \
# 0  {"recordingDevice":"Olympus","microphone":"AOM...                 NaN
# 1  {"recordingDevice":"Olympus","microphone":"AOM...                 NaN
# 2  {"recordingDevice":"Olympus","microphone":"AOM...                 NaN
# 3  {"recordingDevice":"Olympus","microphone":"AOM...                 NaN
# 4  {"recordingDevice":"Olympus","microphone":"AOM...                 NaN
#
#           genus specificEpithet infraspecificEpithet  ...  sex lifeStage  \
# 0  Gelochelidon        nilotica                  NaN  ...  NaN       NaN
# 1  Gelochelidon        nilotica                  NaN  ...  NaN       NaN
# 2  Gelochelidon        nilotica                  NaN  ...  NaN       NaN
# 3  Gelochelidon        nilotica                  NaN  ...  NaN       NaN
# 4  Gelochelidon        nilotica                  NaN  ...  NaN       NaN
#
#       preparations                                         references  \
# 0  field recording  https://data.biodiversitydata.nl/xeno-canto/ob...
# 1  field recording  https://data.biodiversitydata.nl/xeno-canto/ob...
# 2  field recording  https://data.biodiversitydata.nl/xeno-canto/ob...
# 3  field recording  https://data.biodiversitydata.nl/xeno-canto/ob...
# 4  field recording  https://data.biodiversitydata.nl/xeno-canto/ob...
#
#   Associated Taxa        rightsHolder   license  \
# 0             NaN  Christian Kerihuel  CC BY-NC
# 1             NaN  Christian Kerihuel  CC BY-NC
# 2             NaN  Christian Kerihuel  CC BY-NC
# 3             NaN  Christian Kerihuel  CC BY-NC
# 4             NaN  Christian Kerihuel  CC BY-NC
#
#                                            audio_url  media_type  media_rating
# 0  https://xeno-canto.org/sounds/uploaded/VWWRQKF...  StillImage           NaN
# 1  https://xeno-canto.org/sounds/uploaded/VWWRQKF...  StillImage           NaN
# 2  https://xeno-canto.org/sounds/uploaded/VWWRQKF...  StillImage           NaN
# 3  https://xeno-canto.org/sounds/uploaded/VWWRQKF...  StillImage           NaN
# 4  https://xeno-canto.org/sounds/uploaded/VWWRQKF...       Sound           4.0
#
# [5 rows x 40 columns]

# %% [markdown]
# Comprobación de la calidad de porcentaje de registros donde se ha registrado el audio

# %%
# Calcular qué porcentaje de registros tiene audio_url no nulo
porcentaje_audio = df_spain["audio_url"].notna().mean()

print(f"Porcentaje de registros con audio asociado: {porcentaje_audio:.2%}")
# Out:
# Porcentaje de registros con audio asociado: 99.89%

# %%
# Revisión rápida de las columnas más relevantes
columnas_interes = [
    "id",
    "scientificName",
    "family",
    "vernacularName",
    "eventDate",
    "latitudeDecimal",
    "longitudeDecimal",
    "audio_url"
]

df_spain[columnas_interes].head()
# Out:
#           id         scientificName   family    vernacularName   eventDate  \
# 0  902066@XC  Gelochelidon nilotica  Laridae  Gull-billed Tern  2024-05-11
# 1  902066@XC  Gelochelidon nilotica  Laridae  Gull-billed Tern  2024-05-11
# 2  902066@XC  Gelochelidon nilotica  Laridae  Gull-billed Tern  2024-05-11
# 3  902066@XC  Gelochelidon nilotica  Laridae  Gull-billed Tern  2024-05-11
# 4  902066@XC  Gelochelidon nilotica  Laridae  Gull-billed Tern  2024-05-11
#
#    latitudeDecimal  longitudeDecimal  \
# 0          42.2087            3.0994
# 1          42.2087            3.0994
# 2          42.2087            3.0994
# 3          42.2087            3.0994
# 4          42.2087            3.0994
#
#                                            audio_url
# 0  https://xeno-canto.org/sounds/uploaded/VWWRQKF...
# 1  https://xeno-canto.org/sounds/uploaded/VWWRQKF...
# 2  https://xeno-canto.org/sounds/uploaded/VWWRQKF...
# 3  https://xeno-canto.org/sounds/uploaded/VWWRQKF...
# 4  https://xeno-canto.org/sounds/uploaded/VWWRQKF...
